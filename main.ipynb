# %%
# %pip install pandas xlrd openpyxl xlsxwriter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 723.4 kB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install xls2xlsx
# Out:
# ...
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 825.2 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 2.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 8.4 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 8.7 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.7/757.7 kB 2.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.0/163.0 kB 2.5 MB/s eta 0:00:00 0:00:01
# ...

# %%
# %pip install pandas openpyxl beautifulsoup4 lxml xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas openpyxl xlrd
# %pip install python-calamine
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 1.1 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 4.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import os
from xls2xlsx import XLS2XLSX

# %%
df = pd.read_excel('Datos/Alta Verapaz.xlsx', engine='openpyxl', sheet_name='Alta Verapaz', header=1)
df
# Out:
#                                 CODIGO DISTRITO  DEPARTAMENTO MUNICIPIO  \
# 0                        16-01-0138-46   16-031  ALTA VERAPAZ     COBAN
# 1                        16-01-0139-46   16-031  ALTA VERAPAZ     COBAN
# 2                        16-01-0140-46   16-031  ALTA VERAPAZ     COBAN
# 3                        16-01-0141-46   16-005  ALTA VERAPAZ     COBAN
# 4                        16-01-0142-46   16-005  ALTA VERAPAZ     COBAN
# ..                                 ...      ...           ...       ...
# 371                      16-17-0143-46   16-050  ALTA VERAPAZ   RAXRUHA
# 372                      16-17-0144-46   16-026  ALTA VERAPAZ   RAXRUHA
# 373                      16-17-0147-46   16-026  ALTA VERAPAZ   RAXRUHA
# 374                                NaN      NaN           NaN       NaN
# 375  374 Establecimientos encontrados       NaN           NaN       NaN
#
#                                        ESTABLECIMIENTO  \
# ...

# %%
# Directory containing the .xls files
input_directory = 'Datos'
output_directory = 'Datos2'

# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)

# Loop over all files in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith('.xls'):
        # Construct full file path
        file_path = os.path.join(input_directory, filename)
        # Read the .xls file
        xls = XLS2XLSX(file_path)
        # Create the new .xlsx file path
        new_filename = filename.replace('.xls', '.xlsx')
        new_file_path = os.path.join(output_directory, new_filename)
        xls.to_xlsx(new_file_path)
        print(f"Converted {filename} to {new_filename}")
# Out:
# Converted Quetzaltenango.xls to Quetzaltenango.xlsx
# Converted San Marcos.xls to San Marcos.xlsx
# Converted Retalhuleu.xls to Retalhuleu.xlsx
# Converted Quiche.xls to Quiche.xlsx
# Converted Chiquimula.xls to Chiquimula.xlsx
# Converted Jalapa.xls to Jalapa.xlsx
# Converted Peten.xls to Peten.xlsx
# Converted Guatemala.xls to Guatemala.xlsx
# Converted Chimaltenango.xls to Chimaltenango.xlsx

# %%
from python_calamine.pandas import pandas_monkeypatch
df = pd.read_excel('Datos/Capital.xls', engine='calamine', sheet_name='Capital')
df
# Out:
# ---------------------------------------------------------------------------
# CalamineError                             Traceback (most recent call last)
# Cell In[5], line 2
#       1 from python_calamine.pandas import pandas_monkeypatch
# ----> 2 df = pd.read_excel('Datos/Capital.xls', engine='calamine', sheet_name='Capital')
#       3 df
#
# File ~/ds-project-1/.venv/lib/python3.11/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...
